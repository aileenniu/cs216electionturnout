# %%
import pandas as pd

# %%
# Replace 'your_file.xlsx' with your file name

df = pd.read_excel('Economic_csv.xlsx')  # Adjust skiprows as needed

df

# print(df.head(2))
# Out:
#     Table with row headers in columns A and B and column headers in rows 4 through 6 and 80 through 82  \
# 0    Table 7. Reported Voting and Registration of F...
# 1                               (Numbers in thousands)
# 2                                      Characteristics
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 157                                             NOTES:
# 158  Table 7 is limited to persons who report incom...
# 159   Estimates may not sum to totals due to rounding.
# 160  Information on confidentiality protection, sam...
# 161  Source: U.S. Census Bureau, Current Population...
#
#     Unnamed: 1        Unnamed: 2                Unnamed: 3  \
# 0          NaN               NaN                       NaN
# 1          NaN               NaN                       NaN
# 2          NaN  Total population     United States citizen
# ...
